# %%
s = "baabaa"
new_s = s
result = [char for char in new_s]
result

for i in range(len(result) - 1):
    print(i)
    if result[i] == result[i + 1]:
        print("Y")
        break

print(i)
result.pop(i)
result.pop(i)

result
# Out:
# 0
# 1
# Y
# 1
# ['b', 'b', 'a', 'a']
